# %% [markdown]
# Experimento 1.
# Sea X un dado insesgado. Sea Y un dado conectado a X de la siguiente forma: Si cae un número par en X, en el dado Y también se obtendrá un número par. Si en X cae un número impar, en Y puede caer cualqueir cosa.
#
# Simular 10,000 lanzamientos de dado y obtener la probabilidad conjunta (frecuencia relativa en este caso), esto es, la probabilidad p(X=a, Y=b), con a = (1,2,3,4,5,6) y b = (1,2,3,4,5,6). Obtener:
#
# 1. La entropia conjunta.
# 2. Información mutia IM(X;Y).

# %%
import numpy as np
import random
 
print("---Ejemplo de dado X y dado Y en una simulación aleatoria---")
dadoX = [1,2,3,4,5,6]
dadoY = []
 
aleat = random.randint(1,6)
print("Dado X: ", dadoX[aleat-1])
def sesgoDadoY(aleat):
  # Si cae par entonces:
  if aleat % 2 == 0:
    dadoY = [2,4,6]
    return dadoY
  # Si cae impar:
  else:
    dadoY = [1,2,3,4,5,6]
    return dadoY
  
if aleat % 2 == 0:
  aleat2 = random.randint(1,3)
else:
  aleat2 = random.randint(1,6)
 
print("Dado Y: ", sesgoDadoY(aleat)[aleat2-1])
 
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
 
lista1 = []
lista2 = []
 
index1 = []
index2 = []
index3 = []
index4 = []
index5 = []
index6 = []
 
for i in range(0,10000):
  aleat = random.randint(1,6)
  aleat2 = random.randint(1,3)
 
  if aleat % 2 == 0:
    aleat2 = random.randint(1,3)
  else:
    aleat2 = random.randint(1,6)
 
  dX = dadoX[aleat-1]
  dY = sesgoDadoY(aleat)[aleat2-1]
 
  lista1.append(dX)
  lista2.append(dY)  
  
 
# print(lista1)
# print(lista2)
 
indices1 = [j for j, x in enumerate(lista1) if x == 1]
indices2 = [j for j, x in enumerate(lista1) if x == 2]
indices3 = [j for j, x in enumerate(lista1) if x == 3]
indices4 = [j for j, x in enumerate(lista1) if x == 4]
indices5 = [j for j, x in enumerate(lista1) if x == 5]
indices6 = [j for j, x in enumerate(lista1) if x == 6]
 
 
for i in range (0,len(indices1)):
  if lista2[indices1[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices1[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices1[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices1[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices1[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices1[i]] == 6:
    cdy6 = cdy6+1
index1 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices2)):
  if lista2[indices2[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices2[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices2[i]] == 6:
    cdy6 = cdy6+1
index2 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices3)):
  if lista2[indices3[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices3[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices3[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices3[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices3[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices3[i]] == 6:
    cdy6 = cdy6+1
index3 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices4)):
  if lista2[indices4[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices4[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices4[i]] == 6:
    cdy6 = cdy6+1
index4 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices5)):
  if lista2[indices5[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices5[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices5[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices5[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices5[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices5[i]] == 6:
    cdy6 = cdy6+1
index5 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices6)):
  if lista2[indices6[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices6[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices6[i]] == 6:
    cdy6 = cdy6+1
index6 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
 
from prettytable import PrettyTable
 
 
t = PrettyTable(['DY \\ DX ', 1,2,3,4,5,6])
k = 0
t.add_row([1, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 1
t.add_row([2, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 2
t.add_row([3, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 3
t.add_row([4, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 4
t.add_row([5, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 5
t.add_row([6, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
 
# print(t)
 
 
lista3 = []
 
 
lista3.append(index1)
lista3.append(index2)
lista3.append(index3)
lista3.append(index4)
lista3.append(index5)
lista3.append(index6)
lista3 = np.array(lista3)
# print(lista3[1][3])
suma = sum(index1)+ sum(index2) + sum(index3) + sum(index4) + sum(index5) + sum(index6)
# suma = sum(index1)*sum(np.log2(index1))+ sum(index2)*sum(np.log2(index2)) + sum(index3)*sum(np.log2(index3)) + sum(index4)*sum(np.log2(index4)) + sum(index5)*sum(np.log2(index5))+ sum(index6)*sum(np.log2(index6))
lista4 = []
 
## ---------- ENTROPÍA CONJUNTA -------------
for i in range(0,6):
  for j in range(0,6):
    lista4.append((lista3[i][j]/10000)*(np.log2(lista3[i][j]/10000)))
  
lista4 = np.array(lista4)
lista4 = lista4[np.logical_not(np.isnan(lista4))]
 
infoX = np.log2(1/6)
infoY = (infoX*0.5) + (np.log2(1/3)*0.5)
infomutua = infoX+infoY-sum(lista4)
 
t = PrettyTable(['DY \\ DX ', 1,2,3,4,5,6])
k = 0
t.add_row([1, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 1
t.add_row([2, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 2
t.add_row([3, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 3
t.add_row([4, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 4
t.add_row([5, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 5
t.add_row([6, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
 
print(t)
print("Entropia conjunta: ")
print(-sum(lista4))
print("Información Mutua: ")
print(-infomutua)
# Out:
# ---Ejemplo de dado X y dado Y en una simulación aleatoria---
# Dado X:  1
# Dado Y:  3
# +----------+------+------+------+------+------+------+
# | DY \ DX  |  1   |  2   |  3   |  4   |  5   |  6   |
# +----------+------+------+------+------+------+------+
# |    1     | 2.7  | 0.0  | 2.87 | 0.0  | 2.59 | 0.0  |
# |    2     | 2.85 | 5.45 | 2.51 | 5.78 | 2.97 | 6.06 |
# |    3     | 2.65 | 0.0  | 2.64 | 0.0  | 3.13 | 0.0  |
# |    4     | 2.9  | 5.47 | 2.62 | 5.62 | 3.0  | 5.74 |
# |    5     | 2.72 | 0.0  | 2.56 | 0.0  | 2.8  | 0.0  |
# |    6     | 2.72 | 5.53 | 2.96 | 5.42 | 2.59 | 5.15 |
# +----------+------+------+------+------+------+------+
# Entropia conjunta:
# 4.66563644898916
# Información Mutua:
# 0.0042885524531524055
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:206: RuntimeWarning: divide by zero encountered in log2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:206: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# Experimento 2.
# El estado de Y no depende de X. Simular 10,000 lanzamientos de dado y obtener la probabilidad conjunta (frecuencia relativa en este caso), esto es, la probabilidad p(X=a, Y=b), con a = (1,2,3,4,5,6) y b = (1,2,3,4,5,6). Obtener:
#
# 1. La entropia conjunta.
# 2. Información mutia IM(X;Y).

# %%
import numpy as np
import random

print("---Ejemplo de dado X y dado Y en una simulación aleatoria---")
dadoX = [1,2,3,4,5,6]
dadoY = [1,2,3,4,5,6]

aleat = random.randint(1,6)
print("Dado X: ", dadoX[aleat-1])
def sesgoDadoY(aleat):
  # Si cae par entonces:
  if aleat % 2 == 0:
    dadoY = [2,4,6]
    return dadoY
  # Si cae impar:
  else:
    dadoY = [1,2,3,4,5,6]
    return dadoY
  
if aleat % 2 == 0:
  aleat2 = random.randint(1,3)
else:
  aleat2 = random.randint(1,6)

print("Dado Y: ", sesgoDadoY(aleat)[aleat2-1])

cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0

lista1 = []
lista2 = []

index1 = []
index2 = []
index3 = []
index4 = []
index5 = []
index6 = []

for i in range(0,10000):
  aleat = random.randint(1,6)
  aleat2 = random.randint(1,6)
  
  dX = dadoX[aleat-1]
  dY = dadoY[aleat2-1]

  lista1.append(dX)
  lista2.append(dY)  
  

# print(lista1)
# print(lista2)

indices1 = [j for j, x in enumerate(lista1) if x == 1]
indices2 = [j for j, x in enumerate(lista1) if x == 2]
indices3 = [j for j, x in enumerate(lista1) if x == 3]
indices4 = [j for j, x in enumerate(lista1) if x == 4]
indices5 = [j for j, x in enumerate(lista1) if x == 5]
indices6 = [j for j, x in enumerate(lista1) if x == 6]


for i in range (0,len(indices1)):
  if lista2[indices1[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices1[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices1[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices1[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices1[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices1[i]] == 6:
    cdy6 = cdy6+1
index1 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices2)):
  if lista2[indices2[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices2[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices2[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices2[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices2[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices2[i]] == 6:
    cdy6 = cdy6+1
index2 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices3)):
  if lista2[indices3[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices3[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices3[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices3[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices3[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices3[i]] == 6:
    cdy6 = cdy6+1
index3 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices4)):
  if lista2[indices4[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices4[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices4[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices4[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices4[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices4[i]] == 6:
    cdy6 = cdy6+1
index4 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices5)):
  if lista2[indices5[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices5[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices5[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices5[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices5[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices5[i]] == 6:
    cdy6 = cdy6+1
index5 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6
cdy1 = 0
cdy2 = 0
cdy3 = 0
cdy4 = 0
cdy5 = 0
cdy6 = 0
for i in range (0,len(indices6)):
  if lista2[indices6[i]] == 1:
    cdy1 = cdy1+1
  if lista2[indices6[i]] == 2:
    cdy2 = cdy2+1
  if lista2[indices6[i]] == 3:
    cdy3 = cdy3+1
  if lista2[indices6[i]] == 4:
    cdy4 = cdy4+1
  if lista2[indices6[i]] == 5:
    cdy5 = cdy5+1
  if lista2[indices6[i]] == 6:
    cdy6 = cdy6+1
index6 = cdy1,cdy2,cdy3,cdy4,cdy5,cdy6

from prettytable import PrettyTable


t = PrettyTable(['DY \\ DX ', 1,2,3,4,5,6])
k = 0
t.add_row([1, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 1
t.add_row([2, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 2
t.add_row([3, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 3
t.add_row([4, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 4
t.add_row([5, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])
k = 5
t.add_row([6, index1[k],index2[k],index3[k],index4[k],index5[k],index6[k]])

# print(t)


lista3 = []


lista3.append(index1)
lista3.append(index2)
lista3.append(index3)
lista3.append(index4)
lista3.append(index5)
lista3.append(index6)
lista3 = np.array(lista3)
# print(lista3[1][3])
suma = sum(index1)+ sum(index2) + sum(index3) + sum(index4) + sum(index5) + sum(index6)
# suma = sum(index1)*sum(np.log2(index1))+ sum(index2)*sum(np.log2(index2)) + sum(index3)*sum(np.log2(index3)) + sum(index4)*sum(np.log2(index4)) + sum(index5)*sum(np.log2(index5))+ sum(index6)*sum(np.log2(index6))
lista4 = []


for i in range(0,6):
  for j in range(0,6):
    # rint(lista3[i][j])
    lista4.append((lista3[i][j]/10000)*(np.log2(lista3[i][j]/10000)))
  

lista4 = np.array(lista4)
lista4 = lista4[np.logical_not(np.isnan(lista4))]

info = np.log2(1/6)
infomutua = info+info-sum(lista4)
# print(suma)

t = PrettyTable(['DY \\ DX ', 1,2,3,4,5,6])
k = 0
t.add_row([1, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 1
t.add_row([2, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 2
t.add_row([3, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 3
t.add_row([4, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 4
t.add_row([5, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])
k = 5
t.add_row([6, index1[k]/100,index2[k]/100,index3[k]/100,index4[k]/100,index5[k]/100,index6[k]/100])

print(t)
print("Entropia conjunta: ")
print(-sum(lista4))
print("Información Mutua: ")
print(-infomutua)
# Out:
# ---Ejemplo de dado X y dado Y en una simulación aleatoria---
# Dado X:  3
# Dado Y:  2
# +----------+------+------+------+------+------+------+
# | DY \ DX  |  1   |  2   |  3   |  4   |  5   |  6   |
# +----------+------+------+------+------+------+------+
# |    1     | 2.67 | 2.46 | 2.95 | 2.77 | 2.72 | 2.86 |
# |    2     | 2.57 | 2.78 | 2.86 | 2.61 | 2.85 | 2.59 |
# |    3     | 2.75 | 2.78 | 2.9  | 2.82 | 2.78 | 2.85 |
# |    4     | 2.96 | 2.84 | 2.56 | 2.86 | 2.68 | 2.94 |
# |    5     | 2.95 | 2.61 | 2.67 | 2.78 | 2.87 | 2.92 |
# |    6     | 2.89 | 2.71 | 2.79 | 2.81 | 2.61 | 2.98 |
# +----------+------+------+------+------+------+------+
# Entropia conjunta:
# 5.168337045072237
# Información Mutua:
# 0.0015879563700753607
