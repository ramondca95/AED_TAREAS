# %%
from random import randrange
import random

import numpy as np

from matplotlib import pyplot as plt
x = 0


N = 100


bolitas = 1000

lista2 = []
sesgado = 0.5

for j in range(1,bolitas):
  lista = []
  for i in range(1,N):
    x = random.random()
    if x < sesgado:
      x = 0
    else:
      x = 1
      
      
    lista.append(x)
  # lista2[sum(lista)]=1
  lista2.append(sum(lista))





bins = np.arange(0, N, 1) 

plt.hist(lista2, bins=bins, alpha=1)
plt.title('Gaussiana Tablero de Galton con '+ str(bolitas) + " Bolitas y " + str(N) + " Niveles")
lista.clear()

# %%
from random import randrange
import random

import numpy as np

from matplotlib import pyplot as plt
x = 0


N = 1000

bolitas = 1000
for k in range (1,10):
  lista2 = []
  sesgado = k/10

  for j in range(1,bolitas):
    lista = []
    for i in range(1,N):
      x = random.random()
      if x < sesgado:
        x = 0
      else:
        x = 1
        
        
      lista.append(x)
    # lista2[sum(lista)]=1
    lista2.append(sum(lista))

  



  bins = np.arange(0, N, 1) 

  plt.hist(lista2, bins=bins, alpha=1)
  plt.title('Gaussiana Tablero de Galton con '+ str(bolitas) + " Bolitas y " + str(N) + " Niveles")
  lista.clear()
