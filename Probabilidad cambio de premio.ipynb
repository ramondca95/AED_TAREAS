# %%
import numpy as np
from fractions import Fraction
import matplotlib.pyplot as plt

lista = []
lista2 = []
for x in range (3,10):
  # Número de cajas
  n_cajas = x

  probabilidad = Fraction(1,n_cajas)

  prob2 = (1-Fraction(1,n_cajas))/(n_cajas-2)
  lista.append(prob2)
  lista2.append(x)


plt.plot(lista2,lista)
print(lista)
# Out:
# [Fraction(2, 3), Fraction(3, 8), Fraction(4, 15), Fraction(5, 24), Fraction(6, 35), Fraction(7, 48), Fraction(8, 63)]

# %%
from random import randrange
import random
import matplotlib.pyplot as plt
iteration = 10

lista = []
lista2 = []
for j in range(3,10):
  win = 0
  contador = 0
  for i in range(0,iteration):

    cajas = [0] * j

    cajas[randrange(0,j)] = 1

    # print(cajas)

    decision1 = randrange(0,j)
    cajas.pop(decision1)

    cajas.remove(0)
   
    decision2 = random.choice(cajas)

    if decision2 == 1:
      win = win +1

  lista.append(win/iteration)
  lista2.append(j)
plt.plot(lista2,lista)
